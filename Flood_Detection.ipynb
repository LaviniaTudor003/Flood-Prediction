# %% [markdown]
# <a href="https://colab.research.google.com/github/LaviniaTudor003/Flood-Prediction/blob/main/Flood_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!unzip SEN12FLOOD.zip -d SEN12FLOOD
