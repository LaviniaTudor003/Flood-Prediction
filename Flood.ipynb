# %% [markdown]
# <a href="https://colab.research.google.com/github/LaviniaTudor003/Flood-Prediction/blob/main/Flood.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
# !gdown --id 1EVwWrgxkCW4dHM5DZSyVa7at6yLnqus_
# !unzip SEN12FLOOD.zip -d SEN12FLOOD
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1EVwWrgxkCW4dHM5DZSyVa7at6yLnqus_
# From (redirected): https://drive.google.com/uc?id=1EVwWrgxkCW4dHM5DZSyVa7at6yLnqus_&confirm=t&uuid=849ace47-6bf8-4d81-a6a8-278d96a8b974
# To: /content/SEN12FLOOD.zip
#   7% 923M/13.1G [00:06<01:26, 141MB/s]Traceback (most recent call last):
#   File "/usr/local/bin/gdown", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/gdown/__main__.py", line 172, in main
#     download(
#   File "/usr/local/lib/python3.12/dist-packages/gdown/download.py", line 368, in download
#     for chunk in res.iter_content(chunk_size=CHUNK_SIZE):
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
#Andreea_D
# - preprocesare
# Out:
#   File "/tmp/ipython-input-960849420.py", line 1
#     ana are mere
#         ^
# SyntaxError: invalid syntax

# %%
#Andreea_M
# - antrenare

# %%
#Lavinia_T
# - impartire dataset
